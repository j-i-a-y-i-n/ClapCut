# %%
import pandas as pd

# %%
df = pd.read_csv('hero.csv')
df
# Out:
#       SNShot number  SLShot length in deciseconds  \
# 0                 1                           220
# 1                 2                            60
# 2                 3                            51
# 3                 4                            57
# 4                 5                            20
# 5                 6                            13
# 6                 7                            17
# 7                 8                            17
# 8                 9                            20
# 9                10                            31
# 10               11                            31
# 11               12                            37
# 12               13                            51
# 13               14                            83
# 14               15                            99
# 15               16                           255
# 16               17                            18
# 17               18                            84
# ...

# %%
dflength = df[["SLShot length in deciseconds"]].copy()
dflength
# Out:
#       SLShot length in deciseconds
# 0                              220
# 1                               60
# 2                               51
# 3                               57
# 4                               20
# 5                               13
# 6                               17
# 7                               17
# 8                               20
# 9                               31
# 10                              31
# 11                              37
# 12                              51
# 13                              83
# 14                              99
# 15                             255
# 16                              18
# 17                              84
# 18                              14
# 19                              16
# 20                              19
# 21                              19
# 22                             342
# 23                              24
# 24                              68
# 25                              83
# ...

# %%
type(dflength)
# Out:
# pandas.core.frame.DataFrame

# %%
#this is for a previous dataset that turned out to be wrong
#i wanted to change the h:mm:ss format into just seconds in case a plot doesn't read the h:mm:ss format. 
#not relevant but was proud so i'm keeping it for future reference
time = pd.DatetimeIndex(df['length'])
shotlength = time.hour*60 + time.minute*60 + time.second
shotlength

# %%
dflengthlist = dflength.values.T.tolist()
dflengthstr = str(dflengthlist)
dflengthstr
# Out:
# '[[220, 60, 51, 57, 20, 13, 17, 17, 20, 31, 31, 37, 51, 83, 99, 255, 18, 84, 14, 16, 19, 19, 342, 24, 68, 83, 58, 59, 49, 47, 106, 20, 53, 35, 46, 39, 63, 90, 62, 64, 21, 42, 33, 25, 29, 31, 20, 142, 35, 22, 71, 66, 54, 38, 29, 108, 25, 16, 40, 18, 32, 23, 63, 24, 32, 19, 55, 30, 18, 23, 25, 30, 39, 33, 59, 19, 61, 36, 22, 36, 26, 12, 20, 17, 58, 73, 21, 36, 23, 14, 31, 17, 39, 64, 43, 31, 53, 44, 16, 59, 40, 18, 35, 7, 24, 13, 20, 27, 23, 27, 21, 38, 51, 34, 11, 32, 31, 49, 21, 53, 25, 24, 42, 42, 44, 15, 13, 15, 11, 36, 31, 43, 11, 13, 18, 38, 35, 13, 12, 44, 40, 16, 24, 21, 22, 19, 20, 18, 24, 16, 19, 28, 26, 39, 22, 24, 54, 16, 26, 18, 25, 54, 42, 95, 16, 24, 25, 39, 16, 52, 113, 80, 85, 56, 84, 22, 10, 34, 48, 19, 23, 21, 26, 15, 12, 20, 16, 22, 19, 40, 11, 21, 21, 19, 12, 20, 13, 44, 12, 15, 17, 5, 8, 12, 19, 11, 9, 14, 28, 19, 15, 23, 21, 8, 14, 14, 11, 16, 14, 41, 11, 12, 35, 7, 15, 11, 63, 20, 14, 33, 27, 11, 67, 5, 8, 25, 57, 17, 38, 30, 77, 21, 31, 70, 44, 43, 21, 100, 11,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 1
s1 = (220)
s2 = (60)
s3 = (51)
s4 = (57)
s5 = (20)
s6 = (13)
s7 = (17)
s8 = (17)
s9 = (20)
s10 = (31)
s11 = (31)
s12 = (37)
s13 = (51)
s14 = (83)
s15 = (99)
s16 = (255)
s17 = (18)
s18 = (84)
s19 = (14)
s20 = (16)
s21 = (19)
s22 = (19)
s23 = (342)


ind = np.arange(N)    # the x locations for the groups
width = 0.1       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, s1, width, color='red', bottom=s2)
p2 = plt.bar(ind, s2, width, color='blue', bottom=s3)
p3 = plt.bar(ind, s3, width, color='yellow', bottom=s4)
p4 = plt.bar(ind, s4, width, color='green', bottom=s5)
p5 = plt.bar(ind, s5, width, color='red', bottom=s6)
p6 = plt.bar(ind, s6, width, color='blue', bottom=s7)
p7 = plt.bar(ind, s7, width, color='yellow', bottom=s8)
p8 = plt.bar(ind, s8, width, color='green', bottom=s9)
p9 = plt.bar(ind, s9, width, color='red', bottom=s10)
p10 = plt.bar(ind, s10, width, color='blue', bottom=s11)
p11 = plt.bar(ind, s11, width, color='yellow', bottom=s12)
p12 = plt.bar(ind, s12, width, color='green', bottom=s13)
p13 = plt.bar(ind, s13, width, color='red', bottom=s14)
p14 = plt.bar(ind, s14, width, color='blue', bottom=s15)
p15 = plt.bar(ind, s15, width, color='yellow', bottom=s16)
p16 = plt.bar(ind, s16, width, color='green', bottom=s17)
p17 = plt.bar(ind, s17, width, color='red', bottom=s18)
p18 = plt.bar(ind, s18, width, color='blue', bottom=s19)
p19 = plt.bar(ind, s19, width, color='yellow', bottom=s20)
p20 = plt.bar(ind, s20, width, color='green', bottom=s21)
p21 = plt.bar(ind, s21, width, color='red', bottom=s22)
p22 = plt.bar(ind, s22, width, color='blue', bottom=s23)
p23 = plt.bar(ind, s23, width, color='yellow', bottom=s24)



plt.ylabel('Deciseconds')
plt.title('First 5 Min of Hero')
plt.xticks(ind, ('Hero'))
plt.yticks(np.arange(0, 500, 30))

plt.show()

# %%
N = 1
s1 = (220)
s2 = (60)
s3 = (51)
s4 = (57)
s5 = (20)
s6 = (13)


ind = np.arange(N)    # the x locations for the groups
width = 0.1       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, s1, width, color='red', bottom=s2)
p2 = plt.bar(ind, s2, width, color='blue', bottom=s3)
p3 = plt.bar(ind, s3, width, color='yellow', bottom=s4)
p4 = plt.bar(ind, s4, width, color='green', bottom=s5)
p5 = plt.bar(ind, s5, width, color='red', bottom=s6)
p6 = plt.bar(ind, s6, width, color='blue', )


plt.ylabel('Deciseconds')
plt.title('First 5 Min of Hero')
plt.xticks(ind, ('Hero'))
plt.yticks(np.arange(0, 400, 30))

plt.show()
